# %% [markdown]
# ## Como acertar na Mega Sena
#
# A maioria das pessoas que já ouviram falar sobre os prêmios da mega sena, com certeza já desejaram ganhar pelos um. Não é fácil, uma vez que deve-se apostar nos seis números sorteadoss de 01 a 60. Porém, ao termino desta pesquisa, você com certeza irá mudar a sua forma de jogar.
#
# Com base nas informações de todos os sorteios de 1996 a 2018, esse trabalho irá responder aos seguintes questionamentos:}
# - É interessante apostar em números consecutivos?
# - E apostar em números na mesma linha vertical?
# - Quais dezenas mais e menos sorteados?

# %%
# Importando o pandas e lendo a base de dados.
import pandas as pd
dataset = pd.read_excel('basedados.xlsx')
dataset.head()
# Out:
#    Concurso Data Sorteio  Dezena1  Dezena2  Dezena3  Dezena4  Dezena5  \
# 0         1   1996-03-11       41        5        4       52       30
# 1         2   1996-03-18        9       39       37       49       43
# 2         3   1996-03-25       36       30       10       11       29
# 3         4   1996-04-01        6       59       42       27        1
# 4         5   1996-04-08        1       19       46        6       16
#
#    Dezena6  Arrecadacao_Total  Ganhadores_Sena  Rateio_Sena  Ganhadores_Quina  \
# 0       33                0.0                0         0.00                17
# 1       41                0.0                1   2307162.23                65
# 2       47                0.0                2    391192.51                62
# 3        5                0.0                0         0.00                39
# 4        2                0.0                0         0.00                98
#
# ...
